# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os

# %%
#csv obtained from https://www.eia.gov/electricity/data/state/
#Alaska reports no solar energy production for this time frame
#Measurments are in Megawatts
solar_data = "SolarProduction.csv"
solar_data_df = pd.read_csv(solar_data)

# %%
solar_data_df = solar_data_df.drop(columns=['Grand Total'])

# %%
solar_data_df = solar_data_df.set_index("STATE")

# %%
solar_data_df.to_csv("clean_solar_data.csv")

# %%
solar_data_df
# Out:
#                 2008     2009     2010        2011      2012         2013  \
# STATE
# AL                 0        0        0        0.00         0         0.00
# AR                 0        0        0        0.00         0         0.00
# AZ             29448    28290    31508   166697.56   1910886   4222877.28
# CA           1340962  1294780  1538662  1777658.80   2764600   7627449.58
# CO             36708    51170    84996   209271.22    330898    496904.92
# CT                 0        0        0        0.00         0         0.00
# DE                 0        0        0    16559.60     45118     89454.00
# FL                 0    18940   160880   251452.00    387232    419804.00
# GA                 0        0        0        0.00      5842     28994.60
# HI                36     2780     3540     7186.00      9216     38931.92
# IA                 0        0        0        0.00         0         0.00
# ID                 0        0        0        0.00         0         0.00
# ...
