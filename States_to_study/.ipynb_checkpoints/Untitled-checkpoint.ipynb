# %%
import pandas as pd
from matplotlib import pyplot as plt
import os
import numpy as np
from scipy.stats import linregress
import statistics

# %%
emissions_data_path= "../Renewable_Production_Hypothesis/EmissionsData.csv"
emissions_state_df = pd.read_csv(emissions_data_path)
emissions_state_df=emissions_state_df.rename(columns={"Unnamed: 0":"State"})
emissions_state_df.set_index("State")
# Out:
#              2008        2009        2010        2011        2012        2013  \
# State
# AL     139.666603  120.020443  132.722932  129.812612  123.039324  120.732885
# AK      39.435905   37.788246   38.729384   38.585774   38.039447   35.975289
# AZ     102.125070   93.252826   95.204594   93.282044   91.256850   95.060822
# AR      64.059757   61.367031   65.723403   67.168798   65.940126   68.354108
# CA     379.480916  366.184902  360.953079  346.864178  351.496006  354.219000
# CO      97.064224   92.931686   95.398725   91.694520   90.609881   91.185686
# CT      37.476760   35.720615   36.050835   34.650855   33.929278   34.664613
# DC       3.078350    3.171786    3.209717    3.080198    2.648655    2.826738
# DE      15.588371   11.939328   11.232065   12.191584   13.316142   13.046189
# FL     237.796669  223.440307  241.444374  228.354541  222.060114  221.129496
# GA     171.747435  161.815957  171.351718  156.025685  135.837665  134.180946
# ...

# %%
zomg = emissions_state_df[["2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017"]]
zomg
# Out:
#           2008        2009        2010        2011        2012        2013  \
# 0   139.666603  120.020443  132.722932  129.812612  123.039324  120.732885
# 1    39.435905   37.788246   38.729384   38.585774   38.039447   35.975289
# 2   102.125070   93.252826   95.204594   93.282044   91.256850   95.060822
# 3    64.059757   61.367031   65.723403   67.168798   65.940126   68.354108
# 4   379.480916  366.184902  360.953079  346.864178  351.496006  354.219000
# 5    97.064224   92.931686   95.398725   91.694520   90.609881   91.185686
# 6    37.476760   35.720615   36.050835   34.650855   33.929278   34.664613
# 7     3.078350    3.171786    3.209717    3.080198    2.648655    2.826738
# 8    15.588371   11.939328   11.232065   12.191584   13.316142   13.046189
# 9   237.796669  223.440307  241.444374  228.354541  222.060114  221.129496
# 10  171.747435  161.815957  171.351718  156.025685  135.837665  134.180946
# ...

# %%
change = 0
avg= []
one_list = list(zomg.iloc[0])
for i in range(len(one_list)):
    if i < 9:
        change = ((one_list[i]-one_list[i+1])/one_list[i+1])*100
    else:
        break

# %%
avg
# Out:
# []

# %%
change
# Out:
# 5.369781096321556

# %%
one_list
# Out:
# [139.666603,
#  120.020443,
#  132.72293200000001,
#  129.812612,
#  123.039324,
#  120.73288500000001,
#  123.080771,
#  120.01260800000001,
#  114.87269599999999,
#  109.018634]
